# %% [markdown]
# ## **CREATE ENV WITH REQUIREMENTS**

# %%
pwd

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/8d/4b/b6339340169862935ef5757db7e5869af7576f03148d069869edbd523ef2/numpy-1.17.1-cp37-cp37m-macosx_10_9_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/8d/07/f7d7ced2f97ca3098c16565efbe6b15fafcba53e8d9bdb431e09140514b0/pip-19.2.2-py2.py3-none-any.whl
# ...
#      |████████████████████████████████| 124.0MB 80.3MB/s eta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/fe/2e/b480ee1b75e6d17d2993738670e75c1feeb9ff7f64452153cf018051cc92/typing-3.7.4.1-py3-none-any.whl
# ...
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 2.0.1 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# ERROR: featuretools 0.11.0 has requirement scikit-learn>=0.20.0; python_version >= "3", but you'll have scikit-learn 0.19.2 which is incompatible.
# ...

# %%
#conda list --export > requirements.txt
#When you are ready to distribute your package to other users, they can easily duplicate 
#your environment and 
#the associated dependencies with conda create --name <envname> --file requirements.txt
conda list --export
